# %%
import pandas as pd

# %%
countries = pd.read_csv('countries.csv')
countries.head()
# Out:
#                                                 name  tld cca2   ccn3 cca3  \
# 0                Aruba,Aruba,Aruba,Aruba,Aruba,Aruba  .aw   AW  533.0  ABW
# 1  Afghanistan,Islamic Republic of Afghanistan,جم...  .af   AF    4.0  AFG
# 2  Angola,Republic of Angola,República de Angola,...  .ao   AO   24.0  AGO
# 3                Anguilla,Anguilla,Anguilla,Anguilla  .ai   AI  660.0  AIA
# 4  Åland Islands,Åland Islands,Landskapet Åland,Å...  .ax   AX  248.0  ALA
#
#   cioc  independent               status currency callingCode ...     region  \
# 0  ARU          NaN  officially-assigned      AWG         297 ...   Americas
# 1  AFG          1.0  officially-assigned      AFN          93 ...       Asia
# 2  ANG          1.0  officially-assigned      AOA         244 ...     Africa
# 3  NaN          NaN  officially-assigned      XCD        1264 ...   Americas
# 4  NaN          NaN  officially-assigned      EUR         358 ...     Europe
#
#          subregion            languages  \
# ...

# %%
countries['spellings'] = countries['name']
countries['name'] = countries['name'].apply(lambda n: n.split(',')[0])
countries.head()
# Out:
#             name  tld cca2   ccn3 cca3 cioc  independent               status  \
# 0          Aruba  .aw   AW  533.0  ABW  ARU          NaN  officially-assigned
# 1    Afghanistan  .af   AF    4.0  AFG  AFG          1.0  officially-assigned
# 2         Angola  .ao   AO   24.0  AGO  ANG          1.0  officially-assigned
# 3       Anguilla  .ai   AI  660.0  AIA  NaN          NaN  officially-assigned
# 4  Åland Islands  .ax   AX  248.0  ALA  NaN          NaN  officially-assigned
#
#   currency callingCode                        ...                          \
# 0      AWG         297                        ...
# 1      AFN          93                        ...
# 2      AOA         244                        ...
# 3      XCD        1264                        ...
# 4      EUR         358                        ...
#
#          subregion            languages  \
# 0        Caribbean     Dutch,Papiamento
# 1    Southern Asia  Dari,Pashto,Turkmen
# 2    Middle Africa           Portuguese
# ...

# %%
len(countries)
# Out:
# 250

# %%
countries.columns
# Out:
# Index(['name', 'tld', 'cca2', 'ccn3', 'cca3', 'cioc', 'independent', 'status',
#        'currency', 'callingCode', 'capital', 'altSpellings', 'region',
#        'subregion', 'languages', 'translations', 'latlng', 'demonym',
#        'landlocked', 'borders', 'area', 'flag', 'spellings'],
#       dtype='object')

# %%
from xml.etree import ElementTree
def write_countries_xml_to_file(countries_df, filename):
    root = ElementTree.Element('Countries')
    for i in range(len(countries_df)):
        country = ElementTree.SubElement(root, 'Country')
        for field in ['name', 'languages', 'area', 'capital', 'currency', 'callingCode', 'latlng']:
            sub_element = ElementTree.SubElement(country, field)
            sub_element.text = str(countries_df.loc[i, field])
    root_element = ElementTree.ElementTree(root)
    root_element.write(filename)

# %%
write_countries_xml_to_file(countries, 'countries-full.xml')

# %%
def pandas_df_to_xml(df, field_names, filename, root_tag='items', element_tag='item'):
    root = ElementTree.Element(root_tag)
    for i in range(len(df)):
        item = ElementTree.SubElement(root, element_tag)
        for field in fields:
            sub_element = ElementTree.SubElement(item, field)
            sub_element.text = str(df.loc[i, field])
    root_element = ElementTree.ElementTree(root)
