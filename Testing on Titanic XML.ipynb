# %%
with open('data/titanic_1.xml') as file1:
    xml1 = file1.read()
with open('data/titanic_2.xml') as file2:
    xml2 = file2.read()

# %%
from schemamatching import compare_xmls

# %%
results = compare_xmls(xml1, xml2)

# %%
# %matplotlib inline

# %%
import seaborn as sns
sns.heatmap(results, annot=True)
